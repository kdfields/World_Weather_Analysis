# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 728

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from weather_config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
set_count = 1
record_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                        "Lat": city_lat,
                        "Lng": city_lng,
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Date": city_date,
                        "Current Description": city_desc})

    
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | hobart
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | papasquiaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | thompson
# Processing Record 8 of Set 1 | victoria
# Processing Record 9 of Set 1 | rock springs
# Processing Record 10 of Set 1 | zabol
# Processing Record 11 of Set 1 | korla
# Processing Record 12 of Set 1 | barrow
# Processing Record 13 of Set 1 | manggar
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | eresos
# Processing Record 16 of Set 1 | ilulissat
# Processing Record 17 of Set 1 | avarua
# Processing Record 18 of Set 1 | juifang
# City not found. Skipping...
# Processing Record 19 of Set 1 | ponta do sol
# Processing Record 20 of Set 1 | mogadishu
# Processing Record 21 of Set 1 | bethel
# Processing Record 22 of Set 1 | tuktoyaktuk
# Processing Record 23 of Set 1 | upernavik
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | nitra
# Processing Record 26 of Set 1 | salisbury
# Processing Record 27 of Set 1 | karamken
# City not found. Skipping...
# Processing Record 28 of Set 1 | sorong
# Processing Record 29 of Set 1 | dunedin
# Processing Record 30 of Set 1 | belaya gora
# Processing Record 31 of Set 1 | provideniya
# Processing Record 32 of Set 1 | constitucion
# Processing Record 33 of Set 1 | ancud
# Processing Record 34 of Set 1 | puerto ayora
# Processing Record 35 of Set 1 | port alfred
# Processing Record 36 of Set 1 | tanshui
# City not found. Skipping...
# Processing Record 37 of Set 1 | chore
# City not found. Skipping...
# Processing Record 38 of Set 1 | russell
# Processing Record 39 of Set 1 | kodiak
# Processing Record 40 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 1 | la orilla
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | nishihara
# Processing Record 44 of Set 1 | sault sainte marie
# Processing Record 45 of Set 1 | bredasdorp
# Processing Record 46 of Set 1 | porto novo
# Processing Record 47 of Set 1 | inndyr
# Processing Record 48 of Set 1 | vaini
# Processing Record 49 of Set 1 | saint-pierre
# Processing Record 50 of Set 1 | bambous virieux
# Processing Record 1 of Set 2 | hambantota
# Processing Record 2 of Set 2 | mataura
# Processing Record 3 of Set 2 | albany
# Processing Record 4 of Set 2 | vila velha
# Processing Record 5 of Set 2 | castro
# Processing Record 6 of Set 2 | shakawe
# Processing Record 7 of Set 2 | ola
# Processing Record 8 of Set 2 | bowling green
# Processing Record 9 of Set 2 | ghanzi
# Processing Record 10 of Set 2 | cumberland
# Processing Record 11 of Set 2 | margate
# Processing Record 12 of Set 2 | jamestown
# Processing Record 13 of Set 2 | florianopolis
# Processing Record 14 of Set 2 | aripuana
# Processing Record 15 of Set 2 | chuy
# Processing Record 16 of Set 2 | krasnyy chikoy
# Processing Record 17 of Set 2 | tuatapere
# Processing Record 18 of Set 2 | waingapu
# Processing Record 19 of Set 2 | saint george
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | lompoc
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | rawson
# Processing Record 24 of Set 2 | new norfolk
# Processing Record 25 of Set 2 | xghajra
# City not found. Skipping...
# Processing Record 26 of Set 2 | nanortalik
# Processing Record 27 of Set 2 | beringovskiy
# Processing Record 28 of Set 2 | abonnema
# Processing Record 29 of Set 2 | cape town
# Processing Record 30 of Set 2 | cidreira
# Processing Record 31 of Set 2 | chokurdakh
# Processing Record 32 of Set 2 | port hardy
# Processing Record 33 of Set 2 | souillac
# Processing Record 34 of Set 2 | port elizabeth
# Processing Record 35 of Set 2 | yuancheng
# Processing Record 36 of Set 2 | kumba
# Processing Record 37 of Set 2 | comodoro rivadavia
# Processing Record 38 of Set 2 | nikolskoye
# Processing Record 39 of Set 2 | lubango
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | lagoa
# Processing Record 42 of Set 2 | umuahia
# Processing Record 43 of Set 2 | butaritari
# Processing Record 44 of Set 2 | punta arenas
# Processing Record 45 of Set 2 | charters towers
# Processing Record 46 of Set 2 | qaqortoq
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | poum
# Processing Record 49 of Set 2 | mar del plata
# Processing Record 50 of Set 2 | catia la mar
# Processing Record 1 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 3 | tidore
# City not found. Skipping...
# Processing Record 3 of Set 3 | beni suef
# Processing Record 4 of Set 3 | sao raimundo nonato
# Processing Record 5 of Set 3 | bac lieu
# Processing Record 6 of Set 3 | adeje
# Processing Record 7 of Set 3 | grand-santi
# Processing Record 8 of Set 3 | krym
# Processing Record 9 of Set 3 | barbar
# City not found. Skipping...
# Processing Record 10 of Set 3 | repnoye
# Processing Record 11 of Set 3 | northam
# Processing Record 12 of Set 3 | hay river
# Processing Record 13 of Set 3 | paamiut
# Processing Record 14 of Set 3 | twentynine palms
# Processing Record 15 of Set 3 | svetlogorsk
# Processing Record 16 of Set 3 | pizarro
# Processing Record 17 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 18 of Set 3 | raymond
# Processing Record 19 of Set 3 | millington
# Processing Record 20 of Set 3 | healdsburg
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | kone
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | kirkuk
# Processing Record 25 of Set 3 | deputatskiy
# Processing Record 26 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 27 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 3 | sept-iles
# Processing Record 29 of Set 3 | haines junction
# Processing Record 30 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 31 of Set 3 | biak
# Processing Record 32 of Set 3 | monte patria
# Processing Record 33 of Set 3 | nyurba
# Processing Record 34 of Set 3 | plettenberg bay
# Processing Record 35 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 36 of Set 3 | tabory
# Processing Record 37 of Set 3 | port moresby
# Processing Record 38 of Set 3 | atuona
# Processing Record 39 of Set 3 | gat
# Processing Record 40 of Set 3 | san francisco
# Processing Record 41 of Set 3 | piopio
# Processing Record 42 of Set 3 | hilo
# Processing Record 43 of Set 3 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 3 | narsaq
# Processing Record 45 of Set 3 | khatanga
# Processing Record 46 of Set 3 | mitsamiouli
# Processing Record 47 of Set 3 | kofele
# Processing Record 48 of Set 3 | puerto escondido
# Processing Record 49 of Set 3 | izhma
# Processing Record 50 of Set 3 | cabo san lucas
# Processing Record 1 of Set 4 | aloja
# Processing Record 2 of Set 4 | kapaa
# Processing Record 3 of Set 4 | hun
# Processing Record 4 of Set 4 | jiwani
# Processing Record 5 of Set 4 | tabuk
# Processing Record 6 of Set 4 | airai
# Processing Record 7 of Set 4 | winton
# Processing Record 8 of Set 4 | eregli
# Processing Record 9 of Set 4 | beyneu
# Processing Record 10 of Set 4 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 4 | yulara
# Processing Record 12 of Set 4 | katsuura
# Processing Record 13 of Set 4 | chapais
# Processing Record 14 of Set 4 | kurmanayevka
# Processing Record 15 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 4 | san jose de las lajas
# Processing Record 17 of Set 4 | tiksi
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | bafra
# Processing Record 20 of Set 4 | cocal
# Processing Record 21 of Set 4 | la asuncion
# Processing Record 22 of Set 4 | harper
# Processing Record 23 of Set 4 | vuktyl
# Processing Record 24 of Set 4 | nampula
# Processing Record 25 of Set 4 | praia da vitoria
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | east london
# Processing Record 28 of Set 4 | nelson bay
# Processing Record 29 of Set 4 | lebu
# Processing Record 30 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 4 | astoria
# Processing Record 32 of Set 4 | diego de almagro
# Processing Record 33 of Set 4 | namatanai
# Processing Record 34 of Set 4 | falam
# Processing Record 35 of Set 4 | bosaso
# Processing Record 36 of Set 4 | hanyang
# Processing Record 37 of Set 4 | busayra
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | nova soure
# Processing Record 40 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 4 | tautira
# Processing Record 42 of Set 4 | surt
# Processing Record 43 of Set 4 | sehithwa
# Processing Record 44 of Set 4 | asau
# Processing Record 45 of Set 4 | cherskiy
# Processing Record 46 of Set 4 | hatillo
# Processing Record 47 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 48 of Set 4 | camacha
# Processing Record 49 of Set 4 | dikson
# Processing Record 50 of Set 4 | roald
# Processing Record 1 of Set 5 | tasiilaq
# Processing Record 2 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 5 | dakar
# Processing Record 4 of Set 5 | peleduy
# Processing Record 5 of Set 5 | coquimbo
# Processing Record 6 of Set 5 | college
# Processing Record 7 of Set 5 | semey
# Processing Record 8 of Set 5 | bengkulu
# Processing Record 9 of Set 5 | avera
# Processing Record 10 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 11 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 5 | vredefort
# Processing Record 13 of Set 5 | sitka
# Processing Record 14 of Set 5 | najran
# Processing Record 15 of Set 5 | maldonado
# Processing Record 16 of Set 5 | taoudenni
# Processing Record 17 of Set 5 | mahebourg
# Processing Record 18 of Set 5 | bilibino
# Processing Record 19 of Set 5 | clyde river
# Processing Record 20 of Set 5 | metro
# Processing Record 21 of Set 5 | husavik
# Processing Record 22 of Set 5 | naze
# Processing Record 23 of Set 5 | shimoda
# Processing Record 24 of Set 5 | male
# Processing Record 25 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 26 of Set 5 | toora-khem
# Processing Record 27 of Set 5 | jinchang
# Processing Record 28 of Set 5 | oriximina
# Processing Record 29 of Set 5 | luderitz
# Processing Record 30 of Set 5 | esperance
# Processing Record 31 of Set 5 | mkushi
# Processing Record 32 of Set 5 | pokrovskoye
# Processing Record 33 of Set 5 | bata
# Processing Record 34 of Set 5 | shambu
# Processing Record 35 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 36 of Set 5 | walvis bay
# Processing Record 37 of Set 5 | makakilo city
# Processing Record 38 of Set 5 | half moon bay
# Processing Record 39 of Set 5 | faanui
# Processing Record 40 of Set 5 | puerto ayacucho
# Processing Record 41 of Set 5 | salamiyah
# Processing Record 42 of Set 5 | cayenne
# Processing Record 43 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 5 | lata
# Processing Record 45 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 5 | san patricio
# Processing Record 47 of Set 5 | pozo colorado
# Processing Record 48 of Set 5 | de-kastri
# Processing Record 49 of Set 5 | saint-philippe
# Processing Record 50 of Set 5 | trincomalee
# Processing Record 1 of Set 6 | revda
# Processing Record 2 of Set 6 | bardiyah
# Processing Record 3 of Set 6 | boende
# Processing Record 4 of Set 6 | tarija
# Processing Record 5 of Set 6 | salalah
# Processing Record 6 of Set 6 | naruto
# Processing Record 7 of Set 6 | hami
# Processing Record 8 of Set 6 | asbe teferi
# Processing Record 9 of Set 6 | sao joao da barra
# Processing Record 10 of Set 6 | saskylakh
# Processing Record 11 of Set 6 | san quintin
# Processing Record 12 of Set 6 | gorontalo
# Processing Record 13 of Set 6 | hamilton
# Processing Record 14 of Set 6 | beloha
# Processing Record 15 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 16 of Set 6 | oranjestad
# Processing Record 17 of Set 6 | rio grande
# Processing Record 18 of Set 6 | kholtoson
# Processing Record 19 of Set 6 | bury saint edmunds
# City not found. Skipping...
# Processing Record 20 of Set 6 | villanueva de la serena
# Processing Record 21 of Set 6 | komsomolskiy
# Processing Record 22 of Set 6 | pisco
# Processing Record 23 of Set 6 | leningradskiy
# Processing Record 24 of Set 6 | arraial do cabo
# Processing Record 25 of Set 6 | bacungan
# Processing Record 26 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 27 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 28 of Set 6 | erzin
# Processing Record 29 of Set 6 | jinchengjiang
# City not found. Skipping...
# Processing Record 30 of Set 6 | show low
# Processing Record 31 of Set 6 | sao filipe
# Processing Record 32 of Set 6 | dyersburg
# Processing Record 33 of Set 6 | aklavik
# Processing Record 34 of Set 6 | urumqi
# Processing Record 35 of Set 6 | bathsheba
# Processing Record 36 of Set 6 | ilheus
# Processing Record 37 of Set 6 | ahipara
# Processing Record 38 of Set 6 | geraldton
# Processing Record 39 of Set 6 | lavra
# Processing Record 40 of Set 6 | broome
# Processing Record 41 of Set 6 | manokwari
# Processing Record 42 of Set 6 | novodugino
# Processing Record 43 of Set 6 | bonga
# Processing Record 44 of Set 6 | kavieng
# Processing Record 45 of Set 6 | gazanjyk
# Processing Record 46 of Set 6 | gus-zheleznyy
# Processing Record 47 of Set 6 | havelock
# Processing Record 48 of Set 6 | sohag
# Processing Record 49 of Set 6 | atar
# Processing Record 50 of Set 6 | pangody
# Processing Record 1 of Set 7 | brandfort
# Processing Record 2 of Set 7 | mbuji-mayi
# Processing Record 3 of Set 7 | faya
# Processing Record 4 of Set 7 | villa rica
# Processing Record 5 of Set 7 | kieta
# Processing Record 6 of Set 7 | somoto
# Processing Record 7 of Set 7 | mutsu
# Processing Record 8 of Set 7 | vizinga
# Processing Record 9 of Set 7 | fort nelson
# Processing Record 10 of Set 7 | doha
# Processing Record 11 of Set 7 | lufilufi
# Processing Record 12 of Set 7 | riyadh
# Processing Record 13 of Set 7 | ampanihy
# Processing Record 14 of Set 7 | port augusta
# Processing Record 15 of Set 7 | ninghai
# Processing Record 16 of Set 7 | isangel
# Processing Record 17 of Set 7 | vao
# Processing Record 18 of Set 7 | zemio
# Processing Record 19 of Set 7 | norsup
# Processing Record 20 of Set 7 | rustenburg
# Processing Record 21 of Set 7 | lorengau
# Processing Record 22 of Set 7 | grindavik
# Processing Record 23 of Set 7 | sambava
# Processing Record 24 of Set 7 | ngunguru
# Processing Record 25 of Set 7 | inverell
# Processing Record 26 of Set 7 | inhambane
# Processing Record 27 of Set 7 | boa vista
# Processing Record 28 of Set 7 | honningsvag
# Processing Record 29 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 7 | banjar
# Processing Record 31 of Set 7 | surovikino
# Processing Record 32 of Set 7 | namibe
# Processing Record 33 of Set 7 | laguna
# Processing Record 34 of Set 7 | tahoua
# Processing Record 35 of Set 7 | nizhniy kuranakh
# Processing Record 36 of Set 7 | palmer
# Processing Record 37 of Set 7 | eskasem
# City not found. Skipping...
# Processing Record 38 of Set 7 | talaya
# Processing Record 39 of Set 7 | bagdarin
# Processing Record 40 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 41 of Set 7 | eydhafushi
# Processing Record 42 of Set 7 | dongkan
# Processing Record 43 of Set 7 | quesnel
# Processing Record 44 of Set 7 | akureyri
# Processing Record 45 of Set 7 | rio gallegos
# Processing Record 46 of Set 7 | imeni poliny osipenko
# Processing Record 47 of Set 7 | coihaique
# Processing Record 48 of Set 7 | dingle
# Processing Record 49 of Set 7 | acarau
# Processing Record 50 of Set 7 | cotonou
# Processing Record 1 of Set 8 | flin flon
# Processing Record 2 of Set 8 | isagarh
# Processing Record 3 of Set 8 | severo-kurilsk
# Processing Record 4 of Set 8 | kahului
# Processing Record 5 of Set 8 | hobyo
# Processing Record 6 of Set 8 | nagato
# Processing Record 7 of Set 8 | wenling
# Processing Record 8 of Set 8 | kirakira
# Processing Record 9 of Set 8 | santa cruz
# Processing Record 10 of Set 8 | ribeira grande
# Processing Record 11 of Set 8 | umtata
# Processing Record 12 of Set 8 | morristown
# Processing Record 13 of Set 8 | flinders
# Processing Record 14 of Set 8 | oranjemund
# Processing Record 15 of Set 8 | praia
# Processing Record 16 of Set 8 | iqaluit
# Processing Record 17 of Set 8 | thinadhoo
# Processing Record 18 of Set 8 | obluche
# City not found. Skipping...
# Processing Record 19 of Set 8 | pevek
# Processing Record 20 of Set 8 | san cristobal
# Processing Record 21 of Set 8 | sovetskaya gavan
# Processing Record 22 of Set 8 | aswan
# Processing Record 23 of Set 8 | sevierville
# Processing Record 24 of Set 8 | solton
# Processing Record 25 of Set 8 | aleksandrov gay
# Processing Record 26 of Set 8 | mildura
# Processing Record 27 of Set 8 | hunza
# City not found. Skipping...
# Processing Record 28 of Set 8 | itaituba
# Processing Record 29 of Set 8 | giyon
# Processing Record 30 of Set 8 | port lincoln
# Processing Record 31 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 32 of Set 8 | tandil
# Processing Record 33 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 8 | tisul
# Processing Record 35 of Set 8 | luebo
# Processing Record 36 of Set 8 | mokhsogollokh
# Processing Record 37 of Set 8 | linhares
# Processing Record 38 of Set 8 | sola
# Processing Record 39 of Set 8 | berlevag
# Processing Record 40 of Set 8 | nueva gerona
# Processing Record 41 of Set 8 | tarudant
# City not found. Skipping...
# Processing Record 42 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 43 of Set 8 | apricena
# Processing Record 44 of Set 8 | mount gambier
# Processing Record 45 of Set 8 | mollendo
# Processing Record 46 of Set 8 | gobabis
# Processing Record 47 of Set 8 | cockburn town
# Processing Record 48 of Set 8 | kremnica
# Processing Record 49 of Set 8 | rorvik
# Processing Record 50 of Set 8 | uba
# Processing Record 1 of Set 9 | ta khmau
# Processing Record 2 of Set 9 | hastings
# Processing Record 3 of Set 9 | broken hill
# Processing Record 4 of Set 9 | codrington
# Processing Record 5 of Set 9 | talnakh
# Processing Record 6 of Set 9 | nemuro
# Processing Record 7 of Set 9 | mbanza-ngungu
# Processing Record 8 of Set 9 | zhoucheng
# Processing Record 9 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 10 of Set 9 | fortuna
# Processing Record 11 of Set 9 | saint-louis
# Processing Record 12 of Set 9 | gizo
# Processing Record 13 of Set 9 | boueni
# Processing Record 14 of Set 9 | tayu
# Processing Record 15 of Set 9 | mirnyy
# Processing Record 16 of Set 9 | potamia
# Processing Record 17 of Set 9 | durban
# Processing Record 18 of Set 9 | solin
# Processing Record 19 of Set 9 | maumere
# Processing Record 20 of Set 9 | bambanglipuro
# Processing Record 21 of Set 9 | sur
# Processing Record 22 of Set 9 | annau
# Processing Record 23 of Set 9 | katherine
# Processing Record 24 of Set 9 | san carlos de bariloche
# Processing Record 25 of Set 9 | almeirim
# Processing Record 26 of Set 9 | fez
# Processing Record 27 of Set 9 | qostanay
# Processing Record 28 of Set 9 | komsomolskoye
# Processing Record 29 of Set 9 | san vicente
# Processing Record 30 of Set 9 | yarada
# Processing Record 31 of Set 9 | svirsk
# Processing Record 32 of Set 9 | bud
# Processing Record 33 of Set 9 | saint-augustin
# Processing Record 34 of Set 9 | saldanha
# Processing Record 35 of Set 9 | acapulco
# Processing Record 36 of Set 9 | lithakia
# Processing Record 37 of Set 9 | vysokogornyy
# Processing Record 38 of Set 9 | ust-koksa
# Processing Record 39 of Set 9 | balkanabat
# Processing Record 40 of Set 9 | kruisfontein
# Processing Record 41 of Set 9 | port huron
# Processing Record 42 of Set 9 | el balyana
# City not found. Skipping...
# Processing Record 43 of Set 9 | wanlaweyn
# Processing Record 44 of Set 9 | marzuq
# Processing Record 45 of Set 9 | gamba
# Processing Record 46 of Set 9 | bugiri
# Processing Record 47 of Set 9 | udachnyy
# Processing Record 48 of Set 9 | porto empedocle
# Processing Record 49 of Set 9 | saint-georges
# Processing Record 50 of Set 9 | yegorlykskaya
# Processing Record 1 of Set 10 | marivan
# Processing Record 2 of Set 10 | vardo
# Processing Record 3 of Set 10 | san andres
# Processing Record 4 of Set 10 | tsabong
# Processing Record 5 of Set 10 | langsa
# Processing Record 6 of Set 10 | daru
# Processing Record 7 of Set 10 | ortigueira
# Processing Record 8 of Set 10 | tamworth
# Processing Record 9 of Set 10 | palmerston
# Processing Record 10 of Set 10 | kolda
# Processing Record 11 of Set 10 | blackwater
# Processing Record 12 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 10 | grand gaube
# Processing Record 14 of Set 10 | kudahuvadhoo
# Processing Record 15 of Set 10 | upington
# Processing Record 16 of Set 10 | wellington
# Processing Record 17 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 10 | saru dornei
# Processing Record 19 of Set 10 | huarmey
# Processing Record 20 of Set 10 | marawi
# Processing Record 21 of Set 10 | mora
# Processing Record 22 of Set 10 | urzhum
# Processing Record 23 of Set 10 | novaya igirma
# Processing Record 24 of Set 10 | a coruna
# Processing Record 25 of Set 10 | kushima
# Processing Record 26 of Set 10 | calgary
# Processing Record 27 of Set 10 | usakos
# Processing Record 28 of Set 10 | lavrentiya
# Processing Record 29 of Set 10 | hailar
# Processing Record 30 of Set 10 | newport
# Processing Record 31 of Set 10 | springfield
# Processing Record 32 of Set 10 | grand river south east
# City not found. Skipping...
# Processing Record 33 of Set 10 | west odessa
# Processing Record 34 of Set 10 | clarence town
# Processing Record 35 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 10 | aksu
# Processing Record 37 of Set 10 | north bend
# Processing Record 38 of Set 10 | meulaboh
# Processing Record 39 of Set 10 | srednekolymsk
# Processing Record 40 of Set 10 | westport
# Processing Record 41 of Set 10 | lincoln
# Processing Record 42 of Set 10 | soubre
# Processing Record 43 of Set 10 | dunkirk
# Processing Record 44 of Set 10 | diamantino
# Processing Record 45 of Set 10 | aginskoye
# Processing Record 46 of Set 10 | ukiah
# Processing Record 47 of Set 10 | morondava
# Processing Record 48 of Set 10 | bullhead city
# Processing Record 49 of Set 10 | bowen
# Processing Record 50 of Set 10 | kinel
# Processing Record 1 of Set 11 | rio brilhante
# Processing Record 2 of Set 11 | luau
# Processing Record 3 of Set 11 | vostok
# Processing Record 4 of Set 11 | fuerte olimpo
# Processing Record 5 of Set 11 | mwinilunga
# Processing Record 6 of Set 11 | yar-sale
# Processing Record 7 of Set 11 | mount isa
# Processing Record 8 of Set 11 | buzmeyin
# Processing Record 9 of Set 11 | nuuk
# Processing Record 10 of Set 11 | zion
# Processing Record 11 of Set 11 | lunca banului
# Processing Record 12 of Set 11 | baiyin
# Processing Record 13 of Set 11 | kloulklubed
# Processing Record 14 of Set 11 | port keats
# Processing Record 15 of Set 11 | boa viagem
# Processing Record 16 of Set 11 | saint-ambroise
# Processing Record 17 of Set 11 | shingu
# Processing Record 18 of Set 11 | inderborskiy
# City not found. Skipping...
# Processing Record 19 of Set 11 | bure
# Processing Record 20 of Set 11 | sarh
# Processing Record 21 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 22 of Set 11 | vega de alatorre
# Processing Record 23 of Set 11 | churapcha
# Processing Record 24 of Set 11 | maunabo
# Processing Record 25 of Set 11 | byron bay
# Processing Record 26 of Set 11 | yurino
# Processing Record 27 of Set 11 | wanxian
# Processing Record 28 of Set 11 | callaguip
# Processing Record 29 of Set 11 | guerrero negro
# Processing Record 30 of Set 11 | pochutla
# Processing Record 31 of Set 11 | nova olimpia
# Processing Record 32 of Set 11 | pauini
# Processing Record 33 of Set 11 | marica
# Processing Record 34 of Set 11 | vestmannaeyjar
# Processing Record 35 of Set 11 | ndago
# Processing Record 36 of Set 11 | arkhipo-osipovka
# Processing Record 37 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 11 | kankon
# Processing Record 39 of Set 11 | bazarnyye mataki
# Processing Record 40 of Set 11 | ostrovnoy
# Processing Record 41 of Set 11 | torbat-e jam
# Processing Record 42 of Set 11 | arrifes
# Processing Record 43 of Set 11 | prieska
# Processing Record 44 of Set 11 | pedasi
# Processing Record 45 of Set 11 | iberia
# Processing Record 46 of Set 11 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 11 | mnogovershinnyy
# Processing Record 48 of Set 11 | uray
# Processing Record 49 of Set 11 | valreas
# Processing Record 50 of Set 11 | karratha
# Processing Record 1 of Set 12 | sao gabriel da cachoeira
# Processing Record 2 of Set 12 | pacific grove
# Processing Record 3 of Set 12 | okuchi
# Processing Record 4 of Set 12 | zhigansk
# Processing Record 5 of Set 12 | vieques
# Processing Record 6 of Set 12 | warrnambool
# Processing Record 7 of Set 12 | touros
# Processing Record 8 of Set 12 | ahuimanu
# Processing Record 9 of Set 12 | hualmay
# Processing Record 10 of Set 12 | necochea
# Processing Record 11 of Set 12 | pontianak
# Processing Record 12 of Set 12 | coyah
# Processing Record 13 of Set 12 | peniche
# Processing Record 14 of Set 12 | shahr-e babak
# Processing Record 15 of Set 12 | pudozh
# Processing Record 16 of Set 12 | padang
# Processing Record 17 of Set 12 | nosivka
# Processing Record 18 of Set 12 | carlisle
# Processing Record 19 of Set 12 | atambua
# Processing Record 20 of Set 12 | mahibadhoo
# Processing Record 21 of Set 12 | north platte
# Processing Record 22 of Set 12 | keflavik
# Processing Record 23 of Set 12 | ozu
# Processing Record 24 of Set 12 | maragogi
# Processing Record 25 of Set 12 | fairbanks
# Processing Record 26 of Set 12 | myrtle beach
# Processing Record 27 of Set 12 | yamada
# Processing Record 28 of Set 12 | siwana
# Processing Record 29 of Set 12 | kununurra
# Processing Record 30 of Set 12 | solnechnyy
# Processing Record 31 of Set 12 | namie
# Processing Record 32 of Set 12 | grahamstown
# Processing Record 33 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 12 | kathu
# Processing Record 35 of Set 12 | ilhabela
# Processing Record 36 of Set 12 | iwamizawa
# Processing Record 37 of Set 12 | anqing
# Processing Record 38 of Set 12 | sibu
# Processing Record 39 of Set 12 | krasnoselkup
# Processing Record 40 of Set 12 | liyang
# Processing Record 41 of Set 12 | tapes
# Processing Record 42 of Set 12 | klaksvik
# Processing Record 43 of Set 12 | te anau
# Processing Record 44 of Set 12 | rio tinto
# Processing Record 45 of Set 12 | sozopol
# Processing Record 46 of Set 12 | ayr
# Processing Record 47 of Set 12 | ucluelet
# Processing Record 48 of Set 12 | hofn
# Processing Record 49 of Set 12 | quatre cocos
# Processing Record 50 of Set 12 | neuquen
# Processing Record 1 of Set 13 | sinnamary
# Processing Record 2 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 3 of Set 13 | kuching
# Processing Record 4 of Set 13 | dicabisagan
# Processing Record 5 of Set 13 | weligama
# Processing Record 6 of Set 13 | batagay
# Processing Record 7 of Set 13 | waynesboro
# Processing Record 8 of Set 13 | tukrah
# Processing Record 9 of Set 13 | champasak
# Processing Record 10 of Set 13 | valparaiso
# Processing Record 11 of Set 13 | palestine
# Processing Record 12 of Set 13 | isoka
# Processing Record 13 of Set 13 | along
# Processing Record 14 of Set 13 | port-gentil
# Processing Record 15 of Set 13 | sandnessjoen
# Processing Record 16 of Set 13 | houma
# Processing Record 17 of Set 13 | merzig
# Processing Record 18 of Set 13 | bassano
# Processing Record 19 of Set 13 | vigrestad
# Processing Record 20 of Set 13 | inongo
# Processing Record 21 of Set 13 | koutiala
# Processing Record 22 of Set 13 | hervey bay
# Processing Record 23 of Set 13 | kaeo
# Processing Record 24 of Set 13 | jijiga
# Processing Record 25 of Set 13 | tromso
# Processing Record 26 of Set 13 | guaymas
# Processing Record 27 of Set 13 | mayo
# Processing Record 28 of Set 13 | buchanan
# Processing Record 29 of Set 13 | pangnirtung
# Processing Record 30 of Set 13 | temple terrace
# Processing Record 31 of Set 13 | mtwara
# Processing Record 32 of Set 13 | jaisalmer
# Processing Record 33 of Set 13 | coihueco
# Processing Record 34 of Set 13 | manicore
# Processing Record 35 of Set 13 | likasi
# Processing Record 36 of Set 13 | port macquarie
# Processing Record 37 of Set 13 | parana
# Processing Record 38 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 13 | lar
# Processing Record 40 of Set 13 | bisira
# Processing Record 41 of Set 13 | puerto cabello
# Processing Record 42 of Set 13 | woodward
# Processing Record 43 of Set 13 | longido
# Processing Record 44 of Set 13 | high rock
# Processing Record 45 of Set 13 | togur
# Processing Record 46 of Set 13 | kishi
# Processing Record 47 of Set 13 | bangassou
# Processing Record 48 of Set 13 | polis
# Processing Record 49 of Set 13 | capaci
# Processing Record 50 of Set 13 | ishigaki
# Processing Record 1 of Set 14 | tigzirt
# Processing Record 2 of Set 14 | suffolk
# Processing Record 3 of Set 14 | los llanos de aridane
# Processing Record 4 of Set 14 | turkistan
# Processing Record 5 of Set 14 | hasaki
# Processing Record 6 of Set 14 | kampot
# Processing Record 7 of Set 14 | crotone
# Processing Record 8 of Set 14 | corowa
# Processing Record 9 of Set 14 | yicheng
# Processing Record 10 of Set 14 | bismarck
# Processing Record 11 of Set 14 | ongandjera
# Processing Record 12 of Set 14 | alyangula
# Processing Record 13 of Set 14 | itatskiy
# Processing Record 14 of Set 14 | honiara
# Processing Record 15 of Set 14 | havre-saint-pierre
# Processing Record 16 of Set 14 | masuguru
# Processing Record 17 of Set 14 | seoul
# Processing Record 18 of Set 14 | mareeba
# Processing Record 19 of Set 14 | kiruna
# Processing Record 20 of Set 14 | tondano
# Processing Record 21 of Set 14 | mugur-aksy
# Processing Record 22 of Set 14 | portland
# Processing Record 23 of Set 14 | sharya
# Processing Record 24 of Set 14 | bama
# Processing Record 25 of Set 14 | ilanskiy
# Processing Record 26 of Set 14 | bayan
# Processing Record 27 of Set 14 | aykhal
# Processing Record 28 of Set 14 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 14 | sorland
# Processing Record 30 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 31 of Set 14 | stornoway
# Processing Record 32 of Set 14 | burica
# City not found. Skipping...
# Processing Record 33 of Set 14 | shakhrinau
# City not found. Skipping...
# Processing Record 34 of Set 14 | beipiao
# Processing Record 35 of Set 14 | kerchevskiy
# Processing Record 36 of Set 14 | yatou
# Processing Record 37 of Set 14 | dobson
# Processing Record 38 of Set 14 | vandalur
# Processing Record 39 of Set 14 | hovd
# Processing Record 40 of Set 14 | okha
# Processing Record 41 of Set 14 | grafton
# Processing Record 42 of Set 14 | sorumsand
# Processing Record 43 of Set 14 | kamaishi
# Processing Record 44 of Set 14 | anchorage
# Processing Record 45 of Set 14 | baykit
# Processing Record 46 of Set 14 | atka
# City not found. Skipping...
# Processing Record 47 of Set 14 | aviemore
# Processing Record 48 of Set 14 | sile
# Processing Record 49 of Set 14 | podporozhye
# Processing Record 50 of Set 14 | karpathos
# Processing Record 1 of Set 15 | hirado
# Processing Record 2 of Set 15 | kamalganj
# Processing Record 3 of Set 15 | lukoyanov
# Processing Record 4 of Set 15 | outlook
# Processing Record 5 of Set 15 | miri
# Processing Record 6 of Set 15 | marsa matruh
# Processing Record 7 of Set 15 | saint-paul
# Processing Record 8 of Set 15 | port shepstone
# Processing Record 9 of Set 15 | takoradi
# Processing Record 10 of Set 15 | mahabad
# Processing Record 11 of Set 15 | kungurtug
# Processing Record 12 of Set 15 | cap malheureux
# Processing Record 13 of Set 15 | lima
# Processing Record 14 of Set 15 | sokoni
# Processing Record 15 of Set 15 | kurkino
# Processing Record 16 of Set 15 | bonavista
# Processing Record 17 of Set 15 | antofagasta
# Processing Record 18 of Set 15 | andenes
# Processing Record 19 of Set 15 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 15 | salekhard
# Processing Record 21 of Set 15 | karasburg
# Processing Record 22 of Set 15 | samarinda
# Processing Record 23 of Set 15 | shizukuishi
# Processing Record 24 of Set 15 | punahana
# Processing Record 25 of Set 15 | svetlyy
# Processing Record 26 of Set 15 | douglas
# Processing Record 27 of Set 15 | yurimaguas
# Processing Record 28 of Set 15 | malakal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 667

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Hithadhoo  -0.6000   73.0833     80.92        77          12
# 1      Hermanus -34.4187   19.2345     58.80        65          93
# 2        Hobart -42.8794  147.3294     70.27        48          20
# 3       Rikitea -23.1203 -134.9692     79.23        70          47
# 4     Busselton -33.6500  115.3333     71.29        45          26
# 5      Thompson  55.7435  -97.8558    -18.24        69          75
# 6      Victoria  22.2855  114.1577     54.25        33           7
# 7  Rock Springs  41.5875 -109.2029     13.23        76         100
# 8         Zabol  32.2500   67.2500     30.56        96         100
# 9         Korla  41.7597   86.1469     14.79        71         100
#
#    Wind Speed Country                 Date Current Description
# 0       11.03      MV  2023-01-29 01:29:19          few clouds
# 1       18.79      ZA  2023-01-29 01:29:19     overcast clouds
# 2        9.22      AU  2023-01-29 01:27:09          few clouds
# 3       11.56      PF  2023-01-29 01:29:19          light rain
# 4       10.51      AU  2023-01-29 01:29:20    scattered clouds
# 5        5.75      CA  2023-01-29 01:29:20          light snow
# 6       10.00      HK  2023-01-29 01:29:21           clear sky
# 7       12.66      US  2023-01-29 01:29:21          light snow
# 8        4.54      AF  2023-01-29 01:29:21          light snow
# 9        3.87      CN  2023-01-29 01:29:22     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Date', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
city_data_reorder = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[city_data_reorder]

# Display sample data
city_data_df.head()
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Hithadhoo      MV  -0.6000   73.0833     80.92        77          12
# 1   Hermanus      ZA -34.4187   19.2345     58.80        65          93
# 2     Hobart      AU -42.8794  147.3294     70.27        48          20
# 3    Rikitea      PF -23.1203 -134.9692     79.23        70          47
# 4  Busselton      AU -33.6500  115.3333     71.29        45          26
#
#    Wind Speed Current Description
# 0       11.03          few clouds
# 1       18.79     overcast clouds
# 2        9.22          few clouds
# 3       11.56          light rain
# 4       10.51    scattered clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
city_data_csv = "WeatherPy_Database.csv"    
# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(city_data_csv)
